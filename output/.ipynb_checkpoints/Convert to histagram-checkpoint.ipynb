# %%
file = "tc1o.pgm"
text_file = open(file)
for i in range(1,256):
    t = text_file.readline()
    t = t.replace(":",",")
    t = t.replace("answer"," ")
    t = Integer.parseInt(t)
    print(t)
# Out:
# 0 , 80    , 80
#
# 1 , 162    , 162
#
# 2 , 250    , 250
#
# 3 , 343    , 343
#
# 4 , 446    , 446
#
# 5 , 558    , 558
#
# 6 , 684    , 684
#
# 7 , 830    , 830
#
# 8 , 1005    , 1005
#
# 9 , 1234    , 1234
#
# 10 , 1658    , 1658
#
# 11 , 2981    , 2981
#
# 12 , 3086    , 3086
#
# 13 , 3143    , 3143
#
# 14 , 3176    , 3176
#
# 15 , 3191    , 3191
#
# 16 , 3194    , 3194
#
# 17 , 3184    , 3184
#
# 18 , 3157    , 3157
#
# 19 , 3104    , 3104
#
# 20 , 3001    , 3001
#
# 21 , 2731    , 2731
#
# 22 , 930    , 930
#
# 23 , 862    , 862
#
# 24 , 821    , 821
#
# 25 , 798    , 798
#
# 26 , 782    , 782
#
# 27 , 767    , 767
#
# 28 , 752    , 752
#
# 29 , 737    , 737
#
# 30 , 722    , 722
#
# 31 , 708    , 708
#
# 32 , 694    , 694
#
# 33 , 681    , 681
#
# 34 , 667    , 667
#
# 35 , 655    , 655
#
# 36 , 642    , 642
#
# 37 , 630    , 630
#
# 38 , 618    , 618
#
# 39 , 606    , 606
#
# 40 , 594    , 594
#
# 41 , 582    , 582
#
# 42 , 572    , 572
#
# 43 , 560    , 560
#
# ...
